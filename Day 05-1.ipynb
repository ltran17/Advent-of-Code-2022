# %% [markdown]
# See problem description for [day 5](https://adventofcode.com/2022/day/5)

# %%
# STRIPPING WHITESPACE ON THE LEFT is NOT USEFUL in this problem.
def get_lines(file_type='sample'):
    '''
    Read in the lines of today's sample/input file line by line. 
    Assumes the file is in folder called 'inputs/'
    
    Parameters
    ----------
    file_type : str
        Either sample or input
    
    Returns
    -------
    list of inputs stripped of whitespace
    '''
    import datetime
    day = str(datetime.datetime.today().day).zfill(2)
    filename = f'inputs/{day}-{file_type}.txt'
    try:
        with open(filename,'r') as file:
            lines = [line.rstrip() for line in file.readlines()]
        return lines
    except:
        print(filename+' does not exist')

# %%
config = get_lines()

# %%
config
# Out:
# ['    [D]',
#  '[N] [C]',
#  '[Z] [M] [P]',
#  ' 1   2   3',
#  '',
#  'move 1 from 2 to 1',
#  'move 3 from 1 to 3',
#  'move 2 from 2 to 1',
#  'move 1 from 1 to 2']

# %% [markdown]
# First, identify the number of stacks: the first line in config that includes a number. Get the max number.

# %%
def get_number_of_stacks(config):
    for i, line in enumerate(config):
        for ch in line:
            if ch.isdigit():
                return (i, int(line[-1]))
    return -1

# %%
get_number_of_stacks(config)
# Out:
# (3, 3)

# %%
input_config = get_lines('input')

# %%
get_number_of_stacks(input_config)
# Out:
# (8, 9)

# %% [markdown]
# Next, get the value for a level of a stack. If it exists, it will be in location `1 + (stack_number-1)*4`. Stack numbering starts at 1!

# %%
labels, num_stacks = get_number_of_stacks(config)
labels, num_stacks
# Out:
# (3, 3)

# %%
def get_value(line, stack):
    try:
        ch = line[1+(stack-1)*4]
        if ch.isalpha():
            print(ch)
            return ch
        else:
            print('no value: before last valid')
            return None
    except:
        print('no value: after last valid')
        return None

# %%
get_value(config[0],1)
# Out:
# no value: before last valid

# %%
get_value(config[0],2)
# Out:
# D
# 'D'

# %%
get_value(config[0],3)
# Out:
# no value: after last valid

# %%
get_value(config[2],1)
# Out:
# Z
# 'Z'

# %%
from queue import LifoQueue
#LifoQueue behaves like a stack
# `put` a value onto a stack, `get` the top value removes the top value, `qsize` to get size of the stack

# %%
def initialize_state(config):
    labels, num_stacks = get_number_of_stacks(config)
    stacks = {i: LifoQueue() for i in range(1,num_stacks+1)}
    for i in range(labels-1,-1,-1):
        for stack in range(1, num_stacks+1):
            crate = get_value(config[i], stack)
#             print(crate)
            if crate is not None:
                stacks[stack].put(crate)
#         print('\n')
    return stacks

# %%
stacks = initialize_state(config)
# Out:
# Z
# M
# P
# N
# C
# no value: after last valid
# no value: before last valid
# D
# no value: after last valid

# %%
stacks
# Out:
# {1: <queue.LifoQueue at 0x1e7a6b68700>,
#  2: <queue.LifoQueue at 0x1e7a6b68ca0>,
#  3: <queue.LifoQueue at 0x1e7a6b68100>}

# %%
problem_stacks = initialize_state(get_lines('input'))
# Out:
# T
# L
# D
# G
# P
# P
# V
# N
# R
# P
# P
# C
# W
# W
# F
# W
# J
# C
# Z
# T
# Z
# T
# C
# J
# G
# S
# Q
# C
# V
# F
# D
# no value: before last valid
# D
# B
# Q
# F
# S
# H
# no value: before last valid
# L
# no value: before last valid
# C
# D
# H
# S
# L
# C
# no value: before last valid
# M
# no value: before last valid
# T
# no value: before last valid
# W
# L
# Q
# G
# no value: before last valid
# V
# no value: before last valid
# S
# no value: before last valid
# no value: before last valid
# V
# N
# no value: before last valid
# no value: before last valid
# C
# no value: before last valid
# Z
# no value: after last valid
# no value: after last valid
# no value: after last valid

# %%
problem_stacks
# Out:
# {1: <queue.LifoQueue at 0x1e7a6b2a310>,
#  2: <queue.LifoQueue at 0x1e7a6b686a0>,
#  3: <queue.LifoQueue at 0x1e7a6b68d60>,
#  4: <queue.LifoQueue at 0x1e7a6b68f40>,
#  5: <queue.LifoQueue at 0x1e7a6b68040>,
#  6: <queue.LifoQueue at 0x1e7a6b68130>,
#  7: <queue.LifoQueue at 0x1e7a6b3c340>,
#  8: <queue.LifoQueue at 0x1e7a6ba50a0>,
#  9: <queue.LifoQueue at 0x1e7a6ba53a0>}

# %% [markdown]
# ### Whew! Stacks have been initialized for inputs
#
# ### Next up...
#
# Extrapolate the moves from the remainder of the file.

# %%
moves = config[labels+2:]
moves
# Out:
# ['move 1 from 2 to 1',
#  'move 3 from 1 to 3',
#  'move 2 from 2 to 1',
#  'move 1 from 1 to 2']

# %%
def extract_moves(move):
    extract = move.split(' ')
    num_to_move = int(extract[1])
    from_stack = int(extract[3])
    to_stack = int(extract[5])
    return (num_to_move, from_stack, to_stack)

extract_moves(moves[1])
# Out:
# (3, 1, 3)

# %%
for move in moves:
    print(extract_moves(move))
# Out:
# (1, 2, 1)
# (3, 1, 3)
# (2, 2, 1)
# (1, 1, 2)

# %%
def check_stack_sizes(stacks):
    for stack in stacks:
        print(stack, stacks[stack].qsize())

# %%
check_stack_sizes(stacks)
# Out:
# 1 2
# 2 3
# 3 1

# %%
check_stack_sizes(problem_stacks)
# Out:
# 1 8
# 2 7
# 3 4
# 4 8
# 5 3
# 6 8
# 7 5
# 8 6
# 9 7

# %%
def make_move(stacks, move):
    num_to_move, from_stack, to_stack = extract_moves(move)
    for n in range(num_to_move):
        crate = stacks[from_stack].get()
        stacks[to_stack].put(crate)
        print(f'{crate} from stack {from_stack} to stack {to_stack}')
    return stacks

# %%
def make_moves(stacks, moves):
    for move in moves:
        stacks = make_move(stacks, move)
    return stacks

# %%
stacks = make_moves(stacks, moves)
# Out:
# D from stack 2 to stack 1
# D from stack 1 to stack 3
# N from stack 1 to stack 3
# Z from stack 1 to stack 3
# C from stack 2 to stack 1
# M from stack 2 to stack 1
# M from stack 1 to stack 2

# %%
check_stack_sizes(stacks)
# Out:
# 1 1
# 2 1
# 3 4

# %%
def get_top_crates(stacks):
    '''
    Leave the state of the stacks alone! 
    '''
    answer = ''
    for stack in stacks:
        ch = stacks[stack].get()
        answer += ch
        stacks[stack].put(ch)
    return answer

# %%
get_top_crates(stacks)
# Out:
# 'CMZ'

# %%
labels, num_stacks = get_number_of_stacks(input_config)

# %%
problem_moves = input_config[labels+2:]

# %%
answer_stacks = make_moves(problem_stacks, problem_moves)
# Out:
# G from stack 2 to stack 1
# C from stack 2 to stack 1
# H from stack 2 to stack 1
# V from stack 2 to stack 1
# T from stack 2 to stack 1
# P from stack 2 to stack 1
# Z from stack 6 to stack 3
# S from stack 6 to stack 3
# T from stack 6 to stack 3
# C from stack 6 to stack 3
# D from stack 6 to stack 5
# C from stack 3 to stack 8
# T from stack 3 to stack 8
# S from stack 3 to stack 8
# Z from stack 3 to stack 8
# F from stack 3 to stack 8
# Z from stack 3 to stack 8
# C from stack 3 to stack 8
# D from stack 3 to stack 8
# D from stack 8 to stack 2
# C from stack 8 to stack 2
# Z from stack 8 to stack 2
# F from stack 8 to stack 2
# Z from stack 8 to stack 2
# S from stack 8 to stack 2
# T from stack 8 to stack 2
# C from stack 8 to stack 2
# W from stack 8 to stack 2
# H from stack 8 to stack 2
# Q from stack 8 to stack 2
# S from stack 8 to stack 2
# J from stack 8 to stack 2
# D from stack 7 to stack 6
# B from stack 7 to stack 6
# P from stack 1 to stack 6
# T from stack 1 to stack 6
# V from stack 1 to stack 6
# H from stack 1 to stack 6
# C from stack 1 to stack 6
# G from stack 1 to stack 6
# N from stack 1 to stack 6
# Q from stack 1 to stack 6
# L from stack 1 to stack 6
# S from stack 1 to stack 6
# J from stack 2 to stack 8
# S from stack 2 to stack 8
# Q from stack 2 to stack 8
# C from stack 4 to stack 2
# V from stack 4 to stack 2
# M from stack 4 to stack 2
# L from stack 4 to stack 2
# D from stack 4 to stack 2
# S from stack 6 to stack 5
# L from stack 6 to stack 5
# Q from stack 6 to stack 5
# N from stack 6 to stack 5
# G from stack 6 to stack 5
# C from stack 6 to stack 5
# H from stack 6 to stack 5
# V from stack 6 to stack 5
# T from stack 6 to stack 5
# P from stack 6 to stack 5
# B from stack 6 to stack 5
# D from stack 6 to stack 5
# J from stack 6 to stack 5
# F from stack 6 to stack 5
# P from stack 6 to stack 5
# C from stack 1 to stack 4
# G from stack 7 to stack 3
# W from stack 7 to stack 3
# C from stack 4 to stack 2
# T from stack 4 to stack 2
# P from stack 5 to stack 1
# F from stack 5 to stack 1
# J from stack 5 to stack 1
# D from stack 5 to stack 1
# B from stack 5 to stack 1
# P from stack 5 to stack 1
# T from stack 5 to stack 1
# V from stack 5 to stack 1
# H from stack 5 to stack 1
# C from stack 5 to stack 1
# G from stack 5 to stack 1
# N from stack 5 to stack 1
# Q from stack 8 to stack 9
# S from stack 8 to stack 9
# J from stack 8 to stack 9
# N from stack 8 to stack 9
# N from stack 1 to stack 3
# G from stack 1 to stack 3
# C from stack 1 to stack 3
# H from stack 1 to stack 3
# V from stack 1 to stack 3
# T from stack 1 to stack 3
# P from stack 1 to stack 3
# B from stack 1 to stack 3
# D from stack 1 to stack 3
# J from stack 1 to stack 3
# F from stack 1 to stack 3
# P from stack 1 to stack 3
# Z from stack 1 to stack 3
# P from stack 1 to stack 3
# T from stack 1 to stack 3
# N from stack 9 to stack 7
# J from stack 9 to stack 7
# S from stack 9 to stack 7
# Q from stack 9 to stack 7
# V from stack 9 to stack 7
# L from stack 9 to stack 7
# S from stack 9 to stack 7
# F from stack 9 to stack 7
# Q from stack 9 to stack 7
# C from stack 9 to stack 7
# Q from stack 5 to stack 1
# W from stack 4 to stack 8
# C from stack 7 to stack 6
# Q from stack 7 to stack 6
# F from stack 7 to stack 6
# T from stack 2 to stack 6
# C from stack 2 to stack 6
# D from stack 2 to stack 6
# L from stack 2 to stack 6
# M from stack 2 to stack 6
# V from stack 2 to stack 6
# C from stack 2 to stack 6
# H from stack 2 to stack 6
# R from stack 9 to stack 8
# W from stack 2 to stack 3
# C from stack 2 to stack 3
# T from stack 2 to stack 3
# S from stack 2 to stack 3
# Z from stack 2 to stack 3
# G from stack 4 to stack 1
# Z from stack 3 to stack 1
# S from stack 3 to stack 1
# T from stack 3 to stack 1
# C from stack 3 to stack 1
# W from stack 3 to stack 1
# T from stack 3 to stack 1
# P from stack 3 to stack 1
# Z from stack 3 to stack 1
# P from stack 3 to stack 1
# F from stack 3 to stack 1
# J from stack 3 to stack 1
# D from stack 3 to stack 1
# B from stack 3 to stack 1
# P from stack 3 to stack 1
# T from stack 3 to stack 1
# V from stack 3 to stack 1
# F from stack 2 to stack 7
# Z from stack 2 to stack 7
# V from stack 1 to stack 6
# T from stack 1 to stack 6
# P from stack 1 to stack 6
# B from stack 1 to stack 6
# D from stack 1 to stack 6
# J from stack 1 to stack 6
# F from stack 1 to stack 6
# P from stack 1 to stack 6
# Z from stack 1 to stack 6
# P from stack 1 to stack 6
# T from stack 1 to stack 6
# W from stack 1 to stack 6
# C from stack 1 to stack 6
# C from stack 2 to stack 4
# D from stack 2 to stack 9
# L from stack 2 to stack 9
# C from stack 4 to stack 7
# R from stack 8 to stack 2
# W from stack 8 to stack 2
# W from stack 2 to stack 9
# R from stack 2 to stack 9
# C from stack 6 to stack 8
# H from stack 3 to stack 8
# C from stack 3 to stack 8
# T from stack 1 to stack 9
# S from stack 1 to stack 9
# G from stack 3 to stack 9
# N from stack 3 to stack 2
# L from stack 5 to stack 1
# S from stack 5 to stack 1
# D from stack 5 to stack 1
# C from stack 5 to stack 1
# W from stack 5 to stack 1
# G from stack 9 to stack 3
# S from stack 9 to stack 3
# N from stack 2 to stack 3
# W from stack 1 to stack 3
# C from stack 1 to stack 3
# C from stack 3 to stack 2
# W from stack 3 to stack 2
# N from stack 3 to stack 2
# P from stack 5 to stack 7
# P from stack 7 to stack 6
# C from stack 7 to stack 6
# C from stack 8 to stack 3
# H from stack 8 to stack 3
# C from stack 8 to stack 9
# H from stack 3 to stack 4
# C from stack 3 to stack 4
# S from stack 3 to stack 4
# G from stack 3 to stack 4
# W from stack 3 to stack 4
# G from stack 3 to stack 4
# C from stack 9 to stack 6
# T from stack 9 to stack 6
# R from stack 9 to stack 6
# R from stack 6 to stack 4
# T from stack 6 to stack 4
# C from stack 6 to stack 4
# C from stack 6 to stack 4
# P from stack 6 to stack 4
# W from stack 6 to stack 4
# T from stack 6 to stack 4
# P from stack 6 to stack 4
# N from stack 2 to stack 3
# W from stack 2 to stack 6
# C from stack 2 to stack 9
# N from stack 3 to stack 9
# N from stack 9 to stack 5
# C from stack 9 to stack 5
# W from stack 9 to stack 5
# L from stack 9 to stack 5
# D from stack 9 to stack 5
# Z from stack 7 to stack 4
# F from stack 7 to stack 4
# S from stack 7 to stack 4
# L from stack 7 to stack 4
# V from stack 7 to stack 4
# Q from stack 7 to stack 4
# S from stack 7 to stack 4
# S from stack 4 to stack 6
# Q from stack 4 to stack 6
# V from stack 4 to stack 6
# L from stack 4 to stack 6
# S from stack 4 to stack 6
# F from stack 4 to stack 6
# Z from stack 4 to stack 6
# P from stack 4 to stack 6
# T from stack 4 to stack 6
# W from stack 4 to stack 6
# P from stack 4 to stack 6
# C from stack 4 to stack 6
# C from stack 4 to stack 6
# T from stack 4 to stack 6
# D from stack 5 to stack 3
# D from stack 1 to stack 9
# S from stack 1 to stack 9
# L from stack 1 to stack 9
# Z from stack 1 to stack 9
# G from stack 1 to stack 9
# L from stack 5 to stack 4
# W from stack 5 to stack 4
# C from stack 5 to stack 4
# N from stack 5 to stack 4
# Q from stack 1 to stack 7
# D from stack 3 to stack 8
# D from stack 8 to stack 4
# G from stack 9 to stack 7
# Z from stack 9 to stack 7
# L from stack 9 to stack 7
# S from stack 9 to stack 7
# T from stack 6 to stack 5
# C from stack 6 to stack 5
# C from stack 6 to stack 5
# P from stack 6 to stack 5
# W from stack 6 to stack 5
# T from stack 6 to stack 5
# D from stack 4 to stack 6
# N from stack 4 to stack 6
# C from stack 4 to stack 6
# W from stack 4 to stack 6
# L from stack 4 to stack 6
# R from stack 4 to stack 6
# G from stack 4 to stack 6
# W from stack 4 to stack 6
# G from stack 4 to stack 6
# S from stack 4 to stack 6
# D from stack 9 to stack 6
# C from stack 4 to stack 3
# C from stack 3 to stack 6
# H from stack 4 to stack 2
# C from stack 6 to stack 3
# D from stack 6 to stack 3
# S from stack 6 to stack 3
# G from stack 6 to stack 3
# W from stack 6 to stack 3
# G from stack 6 to stack 3
# R from stack 6 to stack 3
# L from stack 6 to stack 3
# W from stack 6 to stack 3
# C from stack 6 to stack 3
# N from stack 6 to stack 3
# D from stack 6 to stack 3
# P from stack 6 to stack 3
# Z from stack 6 to stack 3
# F from stack 6 to stack 3
# S from stack 6 to stack 3
# L from stack 6 to stack 3
# V from stack 6 to stack 3
# Q from stack 6 to stack 3
# S from stack 6 to stack 3
# W from stack 6 to stack 3
# Z from stack 6 to stack 3
# P from stack 6 to stack 3
# F from stack 6 to stack 3
# J from stack 6 to stack 3
# D from stack 6 to stack 3
# B from stack 6 to stack 3
# P from stack 6 to stack 3
# T from stack 6 to stack 3
# V from stack 6 to stack 3
# H from stack 6 to stack 3
# C from stack 6 to stack 3
# V from stack 6 to stack 3
# M from stack 6 to stack 3
# L from stack 6 to stack 3
# H from stack 2 to stack 3
# T from stack 5 to stack 8
# W from stack 5 to stack 8
# P from stack 5 to stack 8
# C from stack 5 to stack 8
# C from stack 5 to stack 4
# T from stack 5 to stack 4
# C from stack 8 to stack 2
# P from stack 8 to stack 2
# W from stack 8 to stack 2
# T from stack 4 to stack 8
# C from stack 4 to stack 8
# H from stack 3 to stack 8
# L from stack 3 to stack 8
# M from stack 3 to stack 8
# V from stack 3 to stack 8
# C from stack 3 to stack 8
# H from stack 3 to stack 8
# V from stack 3 to stack 8
# T from stack 3 to stack 8
# P from stack 3 to stack 8
# B from stack 3 to stack 8
# D from stack 3 to stack 8
# J from stack 3 to stack 8
# F from stack 3 to stack 8
# P from stack 3 to stack 8
# Z from stack 3 to stack 8
# W from stack 3 to stack 8
# S from stack 3 to stack 8
# Q from stack 3 to stack 8
# V from stack 3 to stack 8
# L from stack 3 to stack 8
# S from stack 3 to stack 8
# F from stack 3 to stack 8
# Z from stack 3 to stack 8
# P from stack 3 to stack 8
# D from stack 3 to stack 8
# N from stack 3 to stack 8
# W from stack 2 to stack 9
# P from stack 2 to stack 9
# C from stack 2 to stack 9
# C from stack 3 to stack 5
# W from stack 3 to stack 5
# L from stack 3 to stack 5
# R from stack 3 to stack 5
# G from stack 3 to stack 5
# W from stack 3 to stack 5
# W from stack 5 to stack 7
# G from stack 5 to stack 7
# R from stack 5 to stack 7
# R from stack 7 to stack 4
# G from stack 7 to stack 4
# W from stack 7 to stack 4
# W from stack 4 to stack 5
# G from stack 4 to stack 5
# R from stack 4 to stack 5
# C from stack 9 to stack 5
# C from stack 5 to stack 1
# R from stack 5 to stack 1
# G from stack 5 to stack 1
# W from stack 5 to stack 1
# L from stack 5 to stack 1
# W from stack 5 to stack 1
# N from stack 8 to stack 6
# D from stack 8 to stack 6
# P from stack 8 to stack 5
# Z from stack 8 to stack 5
# F from stack 8 to stack 5
# S from stack 8 to stack 5
# L from stack 8 to stack 5
# V from stack 8 to stack 5
# Q from stack 8 to stack 5
# S from stack 8 to stack 5
# W from stack 8 to stack 5
# Z from stack 8 to stack 5
# P from stack 8 to stack 5
# P from stack 5 to stack 4
# Z from stack 5 to stack 4
# W from stack 5 to stack 4
# S from stack 5 to stack 4
# Q from stack 5 to stack 4
# V from stack 5 to stack 4
# L from stack 5 to stack 4
# S from stack 5 to stack 4
# F from stack 5 to stack 4
# P from stack 9 to stack 7
# P from stack 7 to stack 9
# S from stack 7 to stack 9
# W from stack 1 to stack 4
# L from stack 1 to stack 4
# W from stack 1 to stack 4
# Z from stack 5 to stack 7
# D from stack 6 to stack 1
# N from stack 6 to stack 1
# D from stack 6 to stack 1
# C from stack 6 to stack 1
# T from stack 6 to stack 1
# F from stack 6 to stack 1
# Q from stack 6 to stack 1
# C from stack 6 to stack 1
# Z from stack 7 to stack 9
# L from stack 7 to stack 9
# Z from stack 7 to stack 9
# G from stack 7 to stack 9
# Q from stack 7 to stack 9
# Q from stack 9 to stack 2
# G from stack 9 to stack 2
# Z from stack 9 to stack 2
# L from stack 9 to stack 2
# Z from stack 9 to stack 2
# S from stack 9 to stack 2
# P from stack 9 to stack 2
# P from stack 2 to stack 9
# S from stack 2 to stack 9
# Z from stack 2 to stack 9
# J from stack 7 to stack 1
# N from stack 7 to stack 1
# V from stack 7 to stack 1
# Z from stack 9 to stack 8
# S from stack 9 to stack 8
# P from stack 9 to stack 8
# W from stack 9 to stack 8
# P from stack 5 to stack 6
# C from stack 5 to stack 6
# L from stack 2 to stack 8
# Z from stack 2 to stack 8
# C from stack 6 to stack 9
# P from stack 6 to stack 9
# Z from stack 8 to stack 1
# L from stack 8 to stack 1
# W from stack 8 to stack 1
# P from stack 8 to stack 1
# S from stack 8 to stack 1
# Z from stack 8 to stack 1
# F from stack 8 to stack 1
# J from stack 8 to stack 1
# D from stack 8 to stack 1
# B from stack 8 to stack 1
# P from stack 8 to stack 1
# T from stack 8 to stack 1
# V from stack 8 to stack 1
# G from stack 2 to stack 8
# G from stack 3 to stack 5
# S from stack 3 to stack 5
# D from stack 3 to stack 5
# P from stack 9 to stack 8
# D from stack 5 to stack 4
# S from stack 5 to stack 4
# G from stack 5 to stack 4
# C from stack 9 to stack 3
# Q from stack 2 to stack 3
# P from stack 8 to stack 2
# G from stack 8 to stack 2
# H from stack 8 to stack 2
# C from stack 8 to stack 2
# C from stack 2 to stack 4
# H from stack 2 to stack 4
# G from stack 2 to stack 4
# V from stack 1 to stack 2
# T from stack 1 to stack 2
# P from stack 1 to stack 2
# B from stack 1 to stack 2
# D from stack 1 to stack 2
# J from stack 1 to stack 2
# F from stack 1 to stack 2
# Z from stack 1 to stack 2
# S from stack 1 to stack 2
# P from stack 1 to stack 2
# W from stack 1 to stack 2
# L from stack 1 to stack 2
# Z from stack 1 to stack 2
# V from stack 1 to stack 2
# N from stack 1 to stack 2
# J from stack 1 to stack 2
# C from stack 1 to stack 2
# Q from stack 1 to stack 2
# F from stack 1 to stack 2
# T from stack 1 to stack 8
# C from stack 1 to stack 8
# D from stack 1 to stack 8
# N from stack 1 to stack 8
# D from stack 1 to stack 8
# G from stack 1 to stack 8
# R from stack 1 to stack 8
# C from stack 1 to stack 8
# G from stack 4 to stack 3
# H from stack 4 to stack 1
# F from stack 2 to stack 1
# Q from stack 2 to stack 1
# C from stack 2 to stack 1
# J from stack 2 to stack 1
# N from stack 2 to stack 1
# V from stack 2 to stack 1
# Z from stack 2 to stack 1
# G from stack 3 to stack 1
# Q from stack 3 to stack 1
# C from stack 3 to stack 1
# C from stack 4 to stack 5
# G from stack 4 to stack 5
# S from stack 4 to stack 5
# D from stack 4 to stack 5
# W from stack 4 to stack 5
# L from stack 4 to stack 5
# W from stack 4 to stack 5
# F from stack 4 to stack 5
# S from stack 4 to stack 5
# L from stack 4 to stack 5
# V from stack 4 to stack 5
# Q from stack 4 to stack 5
# S from stack 4 to stack 5
# W from stack 4 to stack 5
# Z from stack 4 to stack 5
# C from stack 1 to stack 7
# L from stack 2 to stack 8
# W from stack 2 to stack 8
# P from stack 2 to stack 8
# S from stack 2 to stack 8
# Z from stack 2 to stack 8
# F from stack 2 to stack 8
# J from stack 2 to stack 8
# D from stack 2 to stack 8
# B from stack 2 to stack 8
# P from stack 2 to stack 8
# T from stack 2 to stack 8
# V from stack 2 to stack 9
# P from stack 2 to stack 9
# C from stack 3 to stack 5
# P from stack 9 to stack 4
# V from stack 9 to stack 4
# T from stack 8 to stack 3
# P from stack 8 to stack 3
# B from stack 8 to stack 3
# D from stack 8 to stack 3
# J from stack 8 to stack 3
# F from stack 8 to stack 3
# Z from stack 8 to stack 3
# S from stack 8 to stack 3
# P from stack 8 to stack 3
# W from stack 8 to stack 3
# L from stack 8 to stack 3
# C from stack 8 to stack 3
# C from stack 5 to stack 1
# Z from stack 5 to stack 1
# W from stack 5 to stack 1
# S from stack 5 to stack 1
# Q from stack 5 to stack 1
# V from stack 5 to stack 1
# L from stack 5 to stack 1
# S from stack 5 to stack 1
# F from stack 5 to stack 1
# W from stack 5 to stack 1
# L from stack 5 to stack 1
# W from stack 5 to stack 1
# D from stack 5 to stack 1
# S from stack 5 to stack 1
# G from stack 5 to stack 1
# C from stack 5 to stack 1
# V from stack 4 to stack 3
# P from stack 4 to stack 3
# P from stack 4 to stack 3
# C from stack 7 to stack 5
# R from stack 8 to stack 6
# G from stack 8 to stack 6
# C from stack 5 to stack 4
# C from stack 4 to stack 9
# C from stack 1 to stack 9
# G from stack 1 to stack 9
# S from stack 1 to stack 9
# D from stack 1 to stack 9
# W from stack 1 to stack 9
# L from stack 1 to stack 9
# W from stack 1 to stack 9
# F from stack 1 to stack 9
# S from stack 1 to stack 9
# L from stack 1 to stack 9
# V from stack 1 to stack 9
# Q from stack 1 to stack 9
# S from stack 1 to stack 9
# W from stack 1 to stack 9
# Z from stack 1 to stack 9
# C from stack 1 to stack 9
# Q from stack 1 to stack 9
# G from stack 1 to stack 9
# P from stack 3 to stack 8
# P from stack 3 to stack 8
# V from stack 3 to stack 8
# C from stack 3 to stack 8
# L from stack 3 to stack 8
# W from stack 3 to stack 8
# P from stack 3 to stack 8
# S from stack 3 to stack 8
# S from stack 8 to stack 2
# P from stack 8 to stack 2
# W from stack 8 to stack 2
# L from stack 8 to stack 2
# C from stack 8 to stack 2
# V from stack 8 to stack 2
# P from stack 8 to stack 2
# P from stack 8 to stack 2
# D from stack 8 to stack 2
# G from stack 9 to stack 2
# Q from stack 9 to stack 2
# C from stack 9 to stack 2
# Z from stack 9 to stack 2
# Z from stack 1 to stack 2
# V from stack 1 to stack 2
# N from stack 1 to stack 2
# J from stack 1 to stack 2
# C from stack 1 to stack 2
# Q from stack 1 to stack 2
# F from stack 1 to stack 2
# H from stack 1 to stack 2
# G from stack 6 to stack 4
# R from stack 6 to stack 4
# H from stack 2 to stack 1
# F from stack 2 to stack 1
# Q from stack 2 to stack 1
# C from stack 2 to stack 1
# J from stack 2 to stack 1
# N from stack 2 to stack 1
# V from stack 2 to stack 1
# Z from stack 2 to stack 1
# Z from stack 2 to stack 1
# C from stack 2 to stack 1
# Q from stack 2 to stack 1
# G from stack 2 to stack 1
# D from stack 2 to stack 1
# P from stack 2 to stack 1
# P from stack 2 to stack 1
# V from stack 2 to stack 1
# C from stack 2 to stack 1
# R from stack 4 to stack 5
# L from stack 2 to stack 6
# W from stack 2 to stack 6
# P from stack 2 to stack 6
# S from stack 2 to stack 9
# P from stack 6 to stack 1
# W from stack 6 to stack 1
# Z from stack 3 to stack 6
# F from stack 3 to stack 6
# J from stack 3 to stack 6
# G from stack 4 to stack 6
# D from stack 3 to stack 2
# B from stack 3 to stack 2
# S from stack 9 to stack 5
# W from stack 9 to stack 5
# S from stack 9 to stack 5
# Q from stack 9 to stack 5
# V from stack 9 to stack 5
# L from stack 9 to stack 5
# S from stack 9 to stack 5
# F from stack 9 to stack 5
# W from stack 9 to stack 5
# L from stack 9 to stack 5
# W from stack 9 to stack 5
# D from stack 9 to stack 5
# S from stack 9 to stack 5
# G from stack 9 to stack 5
# C from stack 9 to stack 5
# C from stack 9 to stack 5
# C from stack 5 to stack 4
# C from stack 5 to stack 4
# G from stack 5 to stack 4
# S from stack 5 to stack 4
# D from stack 5 to stack 4
# W from stack 5 to stack 4
# L from stack 5 to stack 4
# W from stack 5 to stack 4
# F from stack 5 to stack 4
# S from stack 5 to stack 4
# L from stack 5 to stack 4
# V from stack 5 to stack 4
# Q from stack 5 to stack 4
# S from stack 5 to stack 4
# W from stack 5 to stack 8
# S from stack 5 to stack 8
# R from stack 5 to stack 8
# B from stack 2 to stack 4
# R from stack 8 to stack 6
# S from stack 8 to stack 6
# W from stack 8 to stack 6
# N from stack 8 to stack 6
# D from stack 2 to stack 8
# P from stack 3 to stack 9
# T from stack 3 to stack 9
# T from stack 9 to stack 1
# P from stack 9 to stack 1
# D from stack 8 to stack 7
# D from stack 8 to stack 7
# C from stack 8 to stack 7
# T from stack 8 to stack 7
# V from stack 8 to stack 7
# M from stack 8 to stack 7
# L from stack 8 to stack 7
# H from stack 8 to stack 7
# C from stack 8 to stack 7
# T from stack 8 to stack 7
# N from stack 6 to stack 9
# W from stack 6 to stack 9
# S from stack 6 to stack 9
# R from stack 6 to stack 9
# G from stack 6 to stack 9
# J from stack 6 to stack 9
# F from stack 6 to stack 9
# P from stack 1 to stack 5
# T from stack 1 to stack 5
# W from stack 1 to stack 5
# P from stack 1 to stack 5
# C from stack 1 to stack 5
# V from stack 1 to stack 5
# P from stack 1 to stack 5
# P from stack 1 to stack 5
# D from stack 1 to stack 5
# G from stack 1 to stack 5
# Q from stack 1 to stack 5
# C from stack 1 to stack 5
# Z from stack 1 to stack 5
# Z from stack 1 to stack 5
# V from stack 1 to stack 5
# N from stack 1 to stack 5
# B from stack 4 to stack 3
# S from stack 4 to stack 3
# Q from stack 4 to stack 3
# V from stack 4 to stack 3
# L from stack 4 to stack 3
# S from stack 4 to stack 3
# F from stack 4 to stack 3
# T from stack 8 to stack 4
# T from stack 4 to stack 2
# W from stack 4 to stack 2
# L from stack 4 to stack 2
# W from stack 4 to stack 2
# D from stack 4 to stack 2
# N from stack 5 to stack 9
# N from stack 9 to stack 1
# F from stack 9 to stack 1
# J from stack 9 to stack 1
# G from stack 9 to stack 1
# R from stack 9 to stack 1
# R from stack 1 to stack 2
# G from stack 1 to stack 2
# J from stack 1 to stack 2
# F from stack 1 to stack 2
# N from stack 1 to stack 2
# S from stack 9 to stack 7
# W from stack 9 to stack 7
# J from stack 1 to stack 7
# Z from stack 6 to stack 8
# S from stack 4 to stack 5
# G from stack 4 to stack 5
# C from stack 4 to stack 5
# C from stack 4 to stack 5
# L from stack 6 to stack 9
# N from stack 2 to stack 1
# F from stack 2 to stack 1
# J from stack 2 to stack 1
# G from stack 2 to stack 1
# R from stack 2 to stack 1
# D from stack 2 to stack 1
# W from stack 2 to stack 1
# L from stack 2 to stack 1
# W from stack 2 to stack 1
# C from stack 5 to stack 6
# C from stack 5 to stack 6
# G from stack 5 to stack 6
# S from stack 5 to stack 6
# V from stack 5 to stack 6
# Z from stack 5 to stack 6
# Z from stack 5 to stack 6
# C from stack 5 to stack 6
# Q from stack 5 to stack 6
# G from stack 5 to stack 6
# D from stack 5 to stack 6
# L from stack 9 to stack 2
# N from stack 9 to stack 2
# F from stack 3 to stack 4
# S from stack 3 to stack 4
# L from stack 3 to stack 4
# V from stack 3 to stack 4
# V from stack 4 to stack 6
# L from stack 4 to stack 6
# S from stack 4 to stack 6
# F from stack 4 to stack 6
# Q from stack 3 to stack 4
# J from stack 7 to stack 4
# W from stack 7 to stack 4
# S from stack 7 to stack 4
# T from stack 7 to stack 4
# C from stack 7 to stack 4
# H from stack 7 to stack 4
# L from stack 7 to stack 4
# M from stack 7 to stack 4
# V from stack 7 to stack 4
# T from stack 7 to stack 4
# C from stack 7 to stack 4
# C from stack 4 to stack 7
# T from stack 4 to stack 7
# V from stack 4 to stack 7
# M from stack 4 to stack 7
# L from stack 4 to stack 7
# H from stack 4 to stack 7
# C from stack 4 to stack 7
# T from stack 4 to stack 7
# S from stack 4 to stack 7
# S from stack 7 to stack 2
# T from stack 7 to stack 2
# C from stack 7 to stack 2
# H from stack 7 to stack 2
# L from stack 7 to stack 2
# M from stack 7 to stack 2
# V from stack 7 to stack 2
# T from stack 7 to stack 2
# C from stack 7 to stack 2
# D from stack 7 to stack 2
# D from stack 7 to stack 2
# S from stack 3 to stack 5
# B from stack 3 to stack 5
# W from stack 4 to stack 8
# J from stack 4 to stack 8
# B from stack 5 to stack 2
# S from stack 5 to stack 2
# P from stack 5 to stack 2
# P from stack 5 to stack 2
# V from stack 5 to stack 2
# C from stack 5 to stack 2
# P from stack 5 to stack 2
# J from stack 8 to stack 3
# W from stack 5 to stack 1
# J from stack 3 to stack 7
# P from stack 2 to stack 9
# C from stack 2 to stack 9
# V from stack 2 to stack 9
# P from stack 2 to stack 9
# P from stack 2 to stack 9
# S from stack 2 to stack 9
# W from stack 8 to stack 9
# W from stack 9 to stack 2
# S from stack 9 to stack 2
# P from stack 9 to stack 2
# P from stack 9 to stack 2
# V from stack 9 to stack 2
# C from stack 9 to stack 2
# F from stack 6 to stack 2
# S from stack 6 to stack 2
# L from stack 6 to stack 2
# V from stack 6 to stack 2
# D from stack 6 to stack 2
# G from stack 6 to stack 2
# Q from stack 6 to stack 2
# C from stack 6 to stack 2
# Z from stack 6 to stack 2
# Z from stack 6 to stack 2
# V from stack 6 to stack 2
# S from stack 6 to stack 2
# G from stack 6 to stack 2
# C from stack 6 to stack 2
# C from stack 6 to stack 2
# J from stack 7 to stack 2
# J from stack 2 to stack 7
# C from stack 2 to stack 7
# C from stack 2 to stack 7
# G from stack 2 to stack 7
# S from stack 2 to stack 7
# V from stack 2 to stack 7
# Z from stack 2 to stack 7
# Z from stack 2 to stack 7
# C from stack 2 to stack 7
# Q from stack 2 to stack 7
# G from stack 2 to stack 7
# D from stack 2 to stack 7
# V from stack 2 to stack 7
# L from stack 2 to stack 7
# S from stack 2 to stack 7
# F from stack 2 to stack 7
# C from stack 2 to stack 7
# V from stack 2 to stack 7
# P from stack 2 to stack 7
# P from stack 2 to stack 7
# S from stack 2 to stack 7
# W from stack 2 to stack 7
# B from stack 2 to stack 7
# D from stack 2 to stack 7
# D from stack 2 to stack 7
# C from stack 2 to stack 7
# T from stack 2 to stack 7
# V from stack 2 to stack 7
# M from stack 2 to stack 7
# L from stack 2 to stack 7
# H from stack 2 to stack 7
# H from stack 7 to stack 3
# L from stack 7 to stack 3
# M from stack 7 to stack 3
# V from stack 7 to stack 3
# T from stack 7 to stack 3
# C from stack 7 to stack 3
# D from stack 7 to stack 3
# D from stack 7 to stack 3
# B from stack 7 to stack 3
# W from stack 7 to stack 3
# S from stack 7 to stack 3
# P from stack 7 to stack 3
# P from stack 7 to stack 3
# V from stack 7 to stack 3
# C from stack 7 to stack 3
# F from stack 7 to stack 3
# S from stack 7 to stack 3
# L from stack 7 to stack 3
# V from stack 7 to stack 3
# D from stack 7 to stack 3
# G from stack 7 to stack 3
# Q from stack 7 to stack 3
# T from stack 5 to stack 1
# P from stack 5 to stack 1
# C from stack 7 to stack 4
# Z from stack 7 to stack 4
# Z from stack 7 to stack 4
# Z from stack 4 to stack 9
# Z from stack 4 to stack 3
# C from stack 4 to stack 3
# Q from stack 4 to stack 3
# Z from stack 8 to stack 6
# Z from stack 9 to stack 6
# P from stack 1 to stack 5
# T from stack 1 to stack 5
# W from stack 1 to stack 5
# W from stack 1 to stack 5
# L from stack 1 to stack 5
# W from stack 1 to stack 5
# D from stack 1 to stack 5
# R from stack 1 to stack 5
# G from stack 1 to stack 5
# J from stack 1 to stack 5
# F from stack 1 to stack 5
# N from stack 1 to stack 5
# C from stack 1 to stack 5
# Q from stack 1 to stack 5
# F from stack 1 to stack 5
# P from stack 9 to stack 5
# H from stack 1 to stack 8
# Z from stack 6 to stack 8
# Z from stack 6 to stack 8
# Z from stack 8 to stack 4
# Z from stack 4 to stack 6
# Z from stack 6 to stack 9
# Q from stack 3 to stack 1
# C from stack 3 to stack 1
# Z from stack 3 to stack 1
# Q from stack 3 to stack 1
# G from stack 3 to stack 1
# D from stack 3 to stack 1
# V from stack 3 to stack 1
# L from stack 3 to stack 1
# S from stack 3 to stack 1
# F from stack 3 to stack 1
# Z from stack 9 to stack 7
# Z from stack 7 to stack 8
# V from stack 7 to stack 8
# P from stack 5 to stack 1
# F from stack 5 to stack 1
# Q from stack 5 to stack 1
# C from stack 5 to stack 1
# N from stack 5 to stack 1
# F from stack 5 to stack 1
# J from stack 5 to stack 1
# G from stack 5 to stack 1
# R from stack 5 to stack 1
# D from stack 5 to stack 1
# D from stack 1 to stack 4
# R from stack 1 to stack 4
# G from stack 1 to stack 4
# J from stack 1 to stack 4
# F from stack 1 to stack 4
# N from stack 1 to stack 4
# C from stack 1 to stack 4
# Q from stack 1 to stack 4
# F from stack 1 to stack 4
# P from stack 1 to stack 4
# F from stack 1 to stack 4
# S from stack 1 to stack 4
# C from stack 3 to stack 8
# S from stack 4 to stack 8
# F from stack 4 to stack 8
# P from stack 4 to stack 8
# F from stack 4 to stack 8
# Q from stack 4 to stack 8
# C from stack 4 to stack 8
# N from stack 4 to stack 8
# F from stack 4 to stack 8
# J from stack 4 to stack 8
# G from stack 4 to stack 8
# R from stack 4 to stack 8
# R from stack 8 to stack 3
# W from stack 5 to stack 8
# L from stack 5 to stack 8
# W from stack 5 to stack 8
# W from stack 5 to stack 8
# T from stack 5 to stack 8
# P from stack 5 to stack 8
# P from stack 8 to stack 6
# T from stack 8 to stack 6
# W from stack 8 to stack 6
# W from stack 8 to stack 6
# L from stack 8 to stack 6
# W from stack 8 to stack 6
# C from stack 2 to stack 1
# T from stack 2 to stack 1
# S from stack 2 to stack 1
# W from stack 6 to stack 2
# S from stack 1 to stack 6
# T from stack 1 to stack 6
# C from stack 1 to stack 6
# L from stack 1 to stack 6
# V from stack 1 to stack 6
# D from stack 1 to stack 4
# G from stack 1 to stack 4
# Q from stack 1 to stack 4
# W from stack 2 to stack 8
# N from stack 2 to stack 8
# L from stack 2 to stack 8
# T from stack 2 to stack 9
# R from stack 3 to stack 5
# V from stack 3 to stack 5
# P from stack 3 to stack 5
# P from stack 3 to stack 5
# S from stack 3 to stack 5
# W from stack 3 to stack 5
# B from stack 3 to stack 5
# D from stack 3 to stack 5
# Z from stack 1 to stack 3
# C from stack 1 to stack 3
# S from stack 7 to stack 5
# G from stack 7 to stack 5
# C from stack 7 to stack 5
# C from stack 3 to stack 5
# Z from stack 3 to stack 5
# Z from stack 5 to stack 2
# C from stack 5 to stack 2
# C from stack 5 to stack 2
# C from stack 7 to stack 9
# C from stack 9 to stack 1
# T from stack 9 to stack 1
# V from stack 6 to stack 9
# Q from stack 4 to stack 8
# G from stack 4 to stack 8
# L from stack 6 to stack 5
# C from stack 6 to stack 5
# T from stack 6 to stack 5
# S from stack 6 to stack 5
# L from stack 6 to stack 5
# W from stack 6 to stack 7
# V from stack 9 to stack 8
# W from stack 6 to stack 5
# T from stack 6 to stack 5
# P from stack 6 to stack 5
# V from stack 8 to stack 9
# G from stack 8 to stack 9
# Q from stack 8 to stack 9
# L from stack 8 to stack 9
# N from stack 8 to stack 9
# W from stack 8 to stack 9
# G from stack 8 to stack 9
# G from stack 9 to stack 1
# W from stack 9 to stack 1
# N from stack 9 to stack 1
# L from stack 9 to stack 1
# Q from stack 9 to stack 1
# D from stack 4 to stack 8
# D from stack 4 to stack 8
# P from stack 5 to stack 9
# T from stack 5 to stack 9
# W from stack 5 to stack 9
# L from stack 5 to stack 9
# S from stack 5 to stack 9
# T from stack 5 to stack 9
# C from stack 5 to stack 9
# L from stack 5 to stack 9
# G from stack 5 to stack 9
# S from stack 5 to stack 9
# D from stack 5 to stack 9
# C from stack 2 to stack 3
# C from stack 2 to stack 3
# Z from stack 2 to stack 3
# B from stack 5 to stack 8
# W from stack 5 to stack 8
# Z from stack 3 to stack 7
# C from stack 3 to stack 7
# C from stack 3 to stack 7
# D from stack 3 to stack 7
# D from stack 9 to stack 5
# S from stack 9 to stack 5
# G from stack 9 to stack 5
# L from stack 9 to stack 5
# C from stack 9 to stack 5
# T from stack 9 to stack 5
# S from stack 9 to stack 5
# L from stack 9 to stack 5
# W from stack 9 to stack 5
# T from stack 9 to stack 5
# P from stack 9 to stack 5
# D from stack 7 to stack 5
# C from stack 7 to stack 5
# C from stack 7 to stack 5
# C from stack 3 to stack 5
# Q from stack 1 to stack 4
# L from stack 1 to stack 4
# N from stack 1 to stack 4
# W from stack 1 to stack 4
# G from stack 1 to stack 4
# T from stack 1 to stack 4
# C from stack 1 to stack 4
# Q from stack 1 to stack 4
# T from stack 3 to stack 9
# V from stack 3 to stack 9
# M from stack 3 to stack 9
# L from stack 3 to stack 9
# H from stack 3 to stack 9
# C from stack 5 to stack 4
# C from stack 5 to stack 4
# C from stack 5 to stack 4
# D from stack 5 to stack 4
# P from stack 5 to stack 4
# T from stack 5 to stack 4
# W from stack 5 to stack 4
# L from stack 5 to stack 4
# S from stack 5 to stack 4
# T from stack 5 to stack 4
# C from stack 5 to stack 4
# L from stack 5 to stack 4
# G from stack 5 to stack 4
# S from stack 5 to stack 4
# D from stack 5 to stack 4
# D from stack 4 to stack 1
# S from stack 4 to stack 1
# G from stack 4 to stack 1
# L from stack 4 to stack 1
# C from stack 4 to stack 1
# T from stack 4 to stack 1
# S from stack 4 to stack 1
# L from stack 4 to stack 1
# W from stack 8 to stack 1
# B from stack 8 to stack 1
# D from stack 8 to stack 1
# D from stack 8 to stack 1
# J from stack 8 to stack 1
# F from stack 8 to stack 1
# N from stack 8 to stack 1
# C from stack 8 to stack 1
# Q from stack 8 to stack 1
# F from stack 8 to stack 1
# P from stack 8 to stack 1
# F from stack 8 to stack 1
# S from stack 5 to stack 8
# P from stack 5 to stack 8
# P from stack 5 to stack 8
# V from stack 5 to stack 8
# W from stack 4 to stack 5
# T from stack 4 to stack 5
# P from stack 4 to stack 5
# D from stack 4 to stack 5
# C from stack 4 to stack 5
# C from stack 4 to stack 5
# C from stack 4 to stack 5
# Q from stack 4 to stack 5
# C from stack 4 to stack 5
# T from stack 4 to stack 5
# G from stack 4 to stack 5
# W from stack 4 to stack 5
# Z from stack 7 to stack 2
# W from stack 7 to stack 2
# J from stack 7 to stack 2
# W from stack 5 to stack 7
# G from stack 5 to stack 7
# T from stack 5 to stack 7
# C from stack 5 to stack 7
# Q from stack 5 to stack 7
# C from stack 5 to stack 7
# C from stack 5 to stack 7
# C from stack 5 to stack 7
# D from stack 5 to stack 7
# P from stack 5 to stack 7
# T from stack 5 to stack 7
# V from stack 8 to stack 7
# P from stack 8 to stack 7
# P from stack 8 to stack 7
# S from stack 8 to stack 7
# S from stack 8 to stack 7
# C from stack 8 to stack 7
# V from stack 8 to stack 7
# Z from stack 8 to stack 7
# H from stack 9 to stack 8
# L from stack 9 to stack 8
# M from stack 9 to stack 8
# V from stack 9 to stack 8
# T from stack 9 to stack 8
# G from stack 9 to stack 8
# V from stack 9 to stack 8
# W from stack 5 to stack 7
# R from stack 5 to stack 7
# R from stack 7 to stack 8
# W from stack 7 to stack 8
# Z from stack 7 to stack 8
# V from stack 7 to stack 8
# V from stack 8 to stack 4
# Z from stack 8 to stack 4
# W from stack 8 to stack 4
# R from stack 8 to stack 4
# V from stack 8 to stack 4
# G from stack 8 to stack 4
# T from stack 8 to stack 4
# V from stack 8 to stack 4
# M from stack 8 to stack 4
# M from stack 4 to stack 5
# V from stack 4 to stack 5
# T from stack 4 to stack 5
# G from stack 4 to stack 5
# V from stack 4 to stack 5
# R from stack 4 to stack 5
# W from stack 4 to stack 5
# Z from stack 4 to stack 5
# V from stack 4 to stack 5
# N from stack 4 to stack 5
# L from stack 4 to stack 5
# C from stack 7 to stack 8
# S from stack 7 to stack 8
# S from stack 7 to stack 8
# P from stack 7 to stack 8
# P from stack 7 to stack 8
# V from stack 7 to stack 8
# V from stack 8 to stack 7
# P from stack 8 to stack 7
# P from stack 8 to stack 7
# S from stack 8 to stack 7
# S from stack 8 to stack 7
# C from stack 8 to stack 7
# L from stack 8 to stack 7
# H from stack 8 to stack 7
# Z from stack 8 to stack 7
# Z from stack 7 to stack 5
# H from stack 7 to stack 5
# L from stack 7 to stack 5
# C from stack 7 to stack 5
# S from stack 7 to stack 5
# S from stack 7 to stack 5
# P from stack 7 to stack 5
# P from stack 7 to stack 5
# V from stack 7 to stack 5
# T from stack 7 to stack 5
# P from stack 7 to stack 5
# D from stack 7 to stack 5
# C from stack 7 to stack 5
# C from stack 7 to stack 5
# C from stack 7 to stack 5
# Q from stack 7 to stack 5
# C from stack 7 to stack 5
# T from stack 7 to stack 5
# H from stack 8 to stack 1
# H from stack 1 to stack 5
# F from stack 1 to stack 5
# P from stack 1 to stack 5
# F from stack 1 to stack 5
# G from stack 7 to stack 2
# Q from stack 1 to stack 9
# C from stack 1 to stack 9
# N from stack 1 to stack 9
# F from stack 1 to stack 9
# J from stack 1 to stack 9
# D from stack 1 to stack 9
# G from stack 2 to stack 4
# G from stack 4 to stack 3
# D from stack 1 to stack 7
# B from stack 1 to stack 7
# W from stack 1 to stack 7
# Q from stack 4 to stack 2
# Q from stack 2 to stack 5
# J from stack 2 to stack 5
# W from stack 2 to stack 5
# D from stack 9 to stack 5
# J from stack 9 to stack 5
# Z from stack 2 to stack 6
# W from stack 7 to stack 8
# B from stack 7 to stack 8
# D from stack 7 to stack 8
# W from stack 7 to stack 8
# Z from stack 6 to stack 2
# Z from stack 2 to stack 4
# W from stack 8 to stack 5
# D from stack 8 to stack 5
# B from stack 8 to stack 5
# W from stack 8 to stack 5
# F from stack 9 to stack 7
# N from stack 9 to stack 7
# C from stack 9 to stack 7
# Q from stack 9 to stack 5
# Z from stack 4 to stack 3
# Z from stack 3 to stack 8
# G from stack 3 to stack 8
# C from stack 7 to stack 4
# N from stack 7 to stack 4
# Q from stack 5 to stack 8
# W from stack 5 to stack 8
# B from stack 5 to stack 8
# D from stack 5 to stack 8
# W from stack 5 to stack 8
# J from stack 5 to stack 8
# D from stack 5 to stack 8
# W from stack 5 to stack 8
# J from stack 5 to stack 8
# Q from stack 5 to stack 8
# F from stack 5 to stack 8
# P from stack 5 to stack 8
# F from stack 5 to stack 8
# H from stack 5 to stack 8
# T from stack 5 to stack 8
# C from stack 5 to stack 8
# Q from stack 5 to stack 8
# C from stack 5 to stack 8
# C from stack 5 to stack 8
# C from stack 5 to stack 8
# D from stack 5 to stack 8
# P from stack 5 to stack 8
# T from stack 5 to stack 8
# V from stack 5 to stack 8
# P from stack 5 to stack 8
# P from stack 5 to stack 8
# S from stack 5 to stack 8
# S from stack 5 to stack 8
# S from stack 8 to stack 9
# S from stack 9 to stack 3
# C from stack 5 to stack 6
# L from stack 5 to stack 6
# H from stack 5 to stack 6
# Z from stack 5 to stack 6
# L from stack 5 to stack 6
# N from stack 5 to stack 6
# V from stack 5 to stack 2
# Z from stack 5 to stack 2
# W from stack 5 to stack 2
# R from stack 5 to stack 2
# V from stack 5 to stack 2
# S from stack 3 to stack 4
# F from stack 7 to stack 4
# G from stack 5 to stack 6
# S from stack 8 to stack 3
# P from stack 8 to stack 3
# P from stack 8 to stack 3
# V from stack 8 to stack 3
# T from stack 8 to stack 3
# P from stack 8 to stack 3
# D from stack 8 to stack 3
# C from stack 8 to stack 3
# C from stack 8 to stack 3
# C from stack 8 to stack 3
# Q from stack 8 to stack 3
# C from stack 8 to stack 3
# T from stack 8 to stack 3
# H from stack 8 to stack 3
# F from stack 8 to stack 3
# P from stack 8 to stack 3
# L from stack 1 to stack 8
# S from stack 1 to stack 8
# T from stack 1 to stack 8
# C from stack 1 to stack 8
# L from stack 1 to stack 8
# G from stack 1 to stack 8
# S from stack 1 to stack 8
# F from stack 4 to stack 9
# S from stack 4 to stack 9
# N from stack 4 to stack 9
# C from stack 4 to stack 9
# V from stack 2 to stack 4
# R from stack 2 to stack 3
# W from stack 2 to stack 3
# Z from stack 2 to stack 3
# G from stack 6 to stack 8
# N from stack 6 to stack 8
# L from stack 6 to stack 8
# Z from stack 6 to stack 8
# H from stack 6 to stack 8
# L from stack 6 to stack 8
# Z from stack 3 to stack 8
# W from stack 3 to stack 8
# R from stack 3 to stack 8
# P from stack 3 to stack 8
# F from stack 3 to stack 8
# H from stack 3 to stack 8
# T from stack 3 to stack 8
# C from stack 3 to stack 8
# Q from stack 3 to stack 8
# C from stack 3 to stack 8
# V from stack 2 to stack 7
# C from stack 6 to stack 7
# C from stack 8 to stack 5
# Q from stack 8 to stack 5
# C from stack 8 to stack 5
# T from stack 8 to stack 5
# H from stack 8 to stack 5
# F from stack 8 to stack 5
# P from stack 8 to stack 5
# R from stack 8 to stack 5
# W from stack 8 to stack 5
# Z from stack 8 to stack 5
# L from stack 8 to stack 5
# C from stack 7 to stack 8
# V from stack 7 to stack 8
# D from stack 1 to stack 9
# D from stack 9 to stack 5
# C from stack 9 to stack 5
# N from stack 9 to stack 5
# S from stack 9 to stack 5
# F from stack 9 to stack 5
# C from stack 3 to stack 2
# C from stack 3 to stack 2
# D from stack 3 to stack 2
# P from stack 3 to stack 2
# V from stack 4 to stack 2
# T from stack 3 to stack 8
# T from stack 8 to stack 2
# V from stack 8 to stack 2
# C from stack 8 to stack 2
# H from stack 8 to stack 7
# Z from stack 8 to stack 7
# L from stack 8 to stack 7
# N from stack 8 to stack 7
# G from stack 8 to stack 7
# S from stack 8 to stack 7
# G from stack 8 to stack 7
# L from stack 8 to stack 7
# C from stack 8 to stack 7
# T from stack 8 to stack 7
# S from stack 8 to stack 7
# L from stack 8 to stack 7
# F from stack 8 to stack 7
# Q from stack 8 to stack 7
# J from stack 8 to stack 7
# W from stack 8 to stack 7
# D from stack 8 to stack 7
# J from stack 8 to stack 7
# W from stack 8 to stack 7
# W from stack 7 to stack 6
# J from stack 7 to stack 6
# D from stack 7 to stack 6
# W from stack 7 to stack 6
# J from stack 7 to stack 6
# Q from stack 7 to stack 6
# F from stack 5 to stack 2
# S from stack 5 to stack 2
# N from stack 5 to stack 2
# C from stack 5 to stack 2
# F from stack 7 to stack 5
# L from stack 7 to stack 5
# S from stack 7 to stack 5
# T from stack 7 to stack 5
# C from stack 7 to stack 5
# L from stack 7 to stack 5
# G from stack 7 to stack 5
# S from stack 7 to stack 5
# G from stack 7 to stack 5
# N from stack 7 to stack 1
# Q from stack 6 to stack 9
# J from stack 6 to stack 9
# W from stack 6 to stack 9
# D from stack 6 to stack 9
# J from stack 6 to stack 9
# L from stack 7 to stack 4
# W from stack 6 to stack 7
# L from stack 4 to stack 7
# N from stack 1 to stack 2
# L from stack 7 to stack 3
# W from stack 7 to stack 3
# G from stack 5 to stack 9
# S from stack 5 to stack 9
# G from stack 5 to stack 9
# L from stack 5 to stack 9
# C from stack 5 to stack 9
# T from stack 5 to stack 9
# T from stack 9 to stack 1
# C from stack 9 to stack 1
# L from stack 9 to stack 1
# G from stack 9 to stack 1
# S from stack 9 to stack 1
# G from stack 9 to stack 1
# J from stack 9 to stack 1
# D from stack 9 to stack 1
# W from stack 9 to stack 1
# S from stack 5 to stack 4
# L from stack 5 to stack 4
# F from stack 5 to stack 4
# D from stack 5 to stack 4
# L from stack 5 to stack 4
# Z from stack 5 to stack 4
# W from stack 5 to stack 4
# R from stack 5 to stack 4
# P from stack 5 to stack 4
# F from stack 5 to stack 4
# H from stack 5 to stack 4
# T from stack 5 to stack 4
# C from stack 5 to stack 4
# Q from stack 5 to stack 4
# C from stack 5 to stack 4
# T from stack 5 to stack 4
# V from stack 5 to stack 4
# W from stack 3 to stack 1
# L from stack 3 to stack 1
# V from stack 4 to stack 7
# T from stack 4 to stack 7
# C from stack 4 to stack 7
# Q from stack 4 to stack 7
# C from stack 4 to stack 7
# T from stack 4 to stack 7
# H from stack 4 to stack 7
# F from stack 4 to stack 7
# P from stack 4 to stack 7
# R from stack 4 to stack 7
# W from stack 4 to stack 7
# Z from stack 4 to stack 7
# L from stack 4 to stack 7
# V from stack 3 to stack 5
# P from stack 3 to stack 5
# P from stack 3 to stack 5
# L from stack 1 to stack 4
# W from stack 1 to stack 4
# W from stack 1 to stack 4
# D from stack 1 to stack 4
# J from stack 1 to stack 4
# G from stack 1 to stack 4
# S from stack 1 to stack 4
# P from stack 5 to stack 8
# P from stack 5 to stack 2
# V from stack 5 to stack 2
# L from stack 7 to stack 3
# Z from stack 7 to stack 3
# W from stack 7 to stack 3
# R from stack 7 to stack 3
# P from stack 7 to stack 3
# F from stack 7 to stack 3
# M from stack 5 to stack 7
# J from stack 9 to stack 1
# F from stack 3 to stack 2
# P from stack 3 to stack 2
# Q from stack 9 to stack 3
# M from stack 7 to stack 3
# H from stack 7 to stack 3
# T from stack 7 to stack 3
# C from stack 7 to stack 3
# Q from stack 7 to stack 3
# C from stack 7 to stack 3
# T from stack 7 to stack 3
# V from stack 7 to stack 3
# Z from stack 7 to stack 3
# Z from stack 3 to stack 5
# V from stack 3 to stack 5
# T from stack 3 to stack 5
# C from stack 3 to stack 5
# Q from stack 3 to stack 5
# C from stack 3 to stack 5
# T from stack 3 to stack 5
# H from stack 3 to stack 5
# M from stack 3 to stack 5
# Q from stack 3 to stack 5
# S from stack 4 to stack 2
# G from stack 4 to stack 2
# J from stack 4 to stack 2
# D from stack 4 to stack 2
# W from stack 4 to stack 2
# W from stack 4 to stack 2
# L from stack 4 to stack 2
# D from stack 4 to stack 2
# F from stack 4 to stack 1
# D from stack 2 to stack 4
# L from stack 2 to stack 4
# W from stack 2 to stack 4
# W from stack 2 to stack 4
# D from stack 2 to stack 4
# J from stack 2 to stack 4
# G from stack 2 to stack 4
# S from stack 2 to stack 4
# P from stack 2 to stack 4
# F from stack 2 to stack 4
# V from stack 2 to stack 4
# P from stack 2 to stack 4
# N from stack 2 to stack 4
# N from stack 4 to stack 3
# P from stack 4 to stack 3
# V from stack 4 to stack 3
# F from stack 4 to stack 3
# P from stack 4 to stack 3
# Q from stack 5 to stack 9
# H from stack 7 to stack 2
# S from stack 4 to stack 2
# G from stack 4 to stack 2
# J from stack 4 to stack 2
# D from stack 4 to stack 2
# W from stack 4 to stack 2
# W from stack 4 to stack 2
# F from stack 1 to stack 8
# J from stack 1 to stack 8
# G from stack 1 to stack 8
# L from stack 1 to stack 8
# L from stack 4 to stack 6
# D from stack 4 to stack 6
# L from stack 4 to stack 6
# L from stack 8 to stack 9
# G from stack 8 to stack 9
# J from stack 8 to stack 9
# F from stack 8 to stack 9
# P from stack 8 to stack 9
# D from stack 8 to stack 9
# B from stack 8 to stack 9
# W from stack 8 to stack 9
# Q from stack 8 to stack 9
# W from stack 2 to stack 3
# W from stack 2 to stack 3
# D from stack 2 to stack 3
# J from stack 2 to stack 3
# G from stack 2 to stack 3
# S from stack 2 to stack 3
# H from stack 2 to stack 3
# C from stack 2 to stack 3
# N from stack 2 to stack 3
# S from stack 2 to stack 3
# F from stack 2 to stack 3
# C from stack 2 to stack 3
# V from stack 2 to stack 3
# T from stack 2 to stack 3
# V from stack 2 to stack 3
# P from stack 2 to stack 3
# D from stack 2 to stack 3
# G from stack 8 to stack 6
# Z from stack 8 to stack 6
# S from stack 4 to stack 3
# Z from stack 6 to stack 3
# G from stack 6 to stack 3
# C from stack 1 to stack 3
# T from stack 1 to stack 3
# T from stack 3 to stack 4
# C from stack 3 to stack 4
# G from stack 3 to stack 4
# Z from stack 3 to stack 4
# S from stack 3 to stack 4
# D from stack 3 to stack 4
# P from stack 3 to stack 4
# V from stack 3 to stack 4
# T from stack 3 to stack 4
# V from stack 3 to stack 4
# C from stack 3 to stack 4
# F from stack 3 to stack 4
# S from stack 3 to stack 4
# Q from stack 9 to stack 8
# W from stack 9 to stack 8
# B from stack 9 to stack 8
# D from stack 9 to stack 8
# P from stack 9 to stack 8
# F from stack 9 to stack 8
# J from stack 9 to stack 8
# G from stack 9 to stack 8
# S from stack 4 to stack 6
# F from stack 4 to stack 6
# C from stack 4 to stack 6
# V from stack 4 to stack 6
# T from stack 4 to stack 6
# V from stack 4 to stack 6
# P from stack 4 to stack 6
# M from stack 5 to stack 6
# H from stack 5 to stack 6
# T from stack 5 to stack 6
# G from stack 8 to stack 2
# J from stack 8 to stack 2
# F from stack 8 to stack 2
# P from stack 8 to stack 2
# D from stack 8 to stack 2
# T from stack 6 to stack 1
# H from stack 6 to stack 1
# M from stack 6 to stack 1
# P from stack 6 to stack 1
# V from stack 6 to stack 1
# T from stack 6 to stack 1
# V from stack 6 to stack 1
# C from stack 6 to stack 1
# F from stack 6 to stack 1
# D from stack 2 to stack 4
# P from stack 2 to stack 4
# F from stack 2 to stack 4
# J from stack 2 to stack 4
# G from stack 2 to stack 4
# C from stack 2 to stack 4
# C from stack 2 to stack 4
# S from stack 6 to stack 9
# L from stack 6 to stack 9
# F from stack 1 to stack 5
# N from stack 3 to stack 8
# C from stack 3 to stack 8
# H from stack 3 to stack 8
# S from stack 3 to stack 8
# G from stack 3 to stack 8
# J from stack 3 to stack 8
# D from stack 3 to stack 8
# W from stack 3 to stack 8
# W from stack 3 to stack 8
# P from stack 3 to stack 8
# F from stack 3 to stack 8
# V from stack 3 to stack 8
# P from stack 3 to stack 8
# N from stack 3 to stack 8
# R from stack 3 to stack 8
# W from stack 3 to stack 8
# Z from stack 3 to stack 8
# L from stack 3 to stack 8
# C from stack 1 to stack 3
# V from stack 1 to stack 3
# T from stack 1 to stack 3
# V from stack 1 to stack 3
# P from stack 1 to stack 3
# D from stack 6 to stack 1
# C from stack 4 to stack 7
# C from stack 4 to stack 7
# G from stack 4 to stack 7
# J from stack 4 to stack 7
# F from stack 4 to stack 7
# P from stack 4 to stack 7
# D from stack 4 to stack 7
# D from stack 4 to stack 7
# S from stack 4 to stack 7
# L from stack 8 to stack 7
# Z from stack 8 to stack 7
# W from stack 8 to stack 7
# R from stack 8 to stack 7
# N from stack 8 to stack 7
# P from stack 8 to stack 7
# V from stack 8 to stack 7
# F from stack 8 to stack 7
# P from stack 8 to stack 7
# W from stack 8 to stack 7
# W from stack 8 to stack 7
# W from stack 7 to stack 5
# W from stack 7 to stack 5
# P from stack 7 to stack 5
# F from stack 7 to stack 5
# V from stack 7 to stack 5
# Z from stack 4 to stack 5
# G from stack 4 to stack 5
# L from stack 6 to stack 2
# P from stack 7 to stack 8
# N from stack 7 to stack 8
# R from stack 7 to stack 8
# W from stack 7 to stack 8
# Z from stack 7 to stack 8
# L from stack 7 to stack 8
# S from stack 7 to stack 8
# D from stack 7 to stack 8
# D from stack 7 to stack 8
# P from stack 7 to stack 8
# F from stack 7 to stack 8
# J from stack 7 to stack 8
# G from stack 7 to stack 8
# C from stack 4 to stack 9
# C from stack 9 to stack 6
# D from stack 1 to stack 5
# M from stack 1 to stack 5
# H from stack 1 to stack 5
# T from stack 1 to stack 5
# C from stack 7 to stack 6
# T from stack 5 to stack 7
# H from stack 5 to stack 7
# M from stack 5 to stack 7
# D from stack 5 to stack 7
# G from stack 5 to stack 7
# Z from stack 5 to stack 7
# V from stack 5 to stack 7
# F from stack 5 to stack 7
# P from stack 5 to stack 7
# W from stack 5 to stack 6
# W from stack 5 to stack 6
# F from stack 5 to stack 6
# C from stack 5 to stack 6
# Q from stack 5 to stack 6
# C from stack 5 to stack 6
# T from stack 5 to stack 6
# V from stack 5 to stack 6
# P from stack 7 to stack 2
# F from stack 7 to stack 2
# V from stack 7 to stack 2
# Z from stack 7 to stack 2
# G from stack 7 to stack 2
# D from stack 7 to stack 2
# M from stack 7 to stack 2
# H from stack 7 to stack 2
# T from stack 7 to stack 2
# C from stack 7 to stack 2
# Z from stack 5 to stack 7
# Z from stack 7 to stack 1
# G from stack 8 to stack 2
# J from stack 8 to stack 2
# F from stack 8 to stack 2
# P from stack 8 to stack 2
# D from stack 8 to stack 2
# D from stack 8 to stack 2
# S from stack 8 to stack 2
# L from stack 8 to stack 2
# Z from stack 8 to stack 2
# W from stack 8 to stack 2
# R from stack 8 to stack 2
# N from stack 8 to stack 2
# P from stack 8 to stack 2
# D from stack 8 to stack 2
# J from stack 8 to stack 2
# G from stack 8 to stack 2
# S from stack 8 to stack 2
# V from stack 6 to stack 7
# T from stack 6 to stack 7
# C from stack 6 to stack 7
# Q from stack 6 to stack 7
# C from stack 6 to stack 7
# F from stack 6 to stack 7
# W from stack 6 to stack 7
# W from stack 6 to stack 7
# C from stack 6 to stack 7
# C from stack 7 to stack 1
# W from stack 7 to stack 1
# W from stack 7 to stack 1
# F from stack 7 to stack 1
# C from stack 7 to stack 1
# Q from stack 7 to stack 1
# C from stack 7 to stack 2
# T from stack 7 to stack 2
# T from stack 4 to stack 2
# T from stack 2 to stack 8
# T from stack 2 to stack 8
# C from stack 2 to stack 8
# S from stack 2 to stack 8
# G from stack 2 to stack 8
# J from stack 2 to stack 8
# D from stack 2 to stack 8
# P from stack 2 to stack 8
# N from stack 2 to stack 8
# R from stack 2 to stack 8
# W from stack 2 to stack 8
# Z from stack 2 to stack 8
# Q from stack 1 to stack 2
# C from stack 1 to stack 2
# F from stack 1 to stack 2
# W from stack 1 to stack 2
# W from stack 1 to stack 2
# C from stack 1 to stack 2
# Z from stack 1 to stack 2
# Z from stack 8 to stack 6
# W from stack 8 to stack 6
# R from stack 8 to stack 6
# N from stack 8 to stack 6
# P from stack 8 to stack 6
# D from stack 8 to stack 6
# J from stack 8 to stack 2
# G from stack 8 to stack 2
# S from stack 8 to stack 2
# V from stack 7 to stack 2
# P from stack 3 to stack 4
# V from stack 3 to stack 4
# V from stack 4 to stack 9
# T from stack 3 to stack 5
# V from stack 3 to stack 5
# C from stack 3 to stack 7
# S from stack 3 to stack 7
# P from stack 4 to stack 6
# S from stack 7 to stack 1
# C from stack 7 to stack 1
# V from stack 2 to stack 7
# S from stack 2 to stack 7
# G from stack 2 to stack 7
# J from stack 2 to stack 7
# Z from stack 2 to stack 7
# C from stack 2 to stack 7
# W from stack 2 to stack 7
# W from stack 7 to stack 1
# C from stack 7 to stack 1
# Z from stack 7 to stack 1
# J from stack 7 to stack 1
# G from stack 7 to stack 1
# S from stack 7 to stack 1
# V from stack 5 to stack 2
# C from stack 8 to stack 4
# T from stack 8 to stack 4
# T from stack 8 to stack 4
# H from stack 8 to stack 4
# C from stack 8 to stack 4
# N from stack 8 to stack 4
# V from stack 9 to stack 7
# L from stack 9 to stack 7
# S from stack 9 to stack 7
# L from stack 9 to stack 7
# T from stack 5 to stack 2
# B from stack 8 to stack 1
# W from stack 8 to stack 1
# Q from stack 8 to stack 1
# Q from stack 9 to stack 4
# L from stack 7 to stack 8
# L from stack 8 to stack 1
# S from stack 7 to stack 8
# L from stack 7 to stack 8
# V from stack 7 to stack 8
# V from stack 7 to stack 8
# Q from stack 4 to stack 2
# P from stack 6 to stack 9
# D from stack 6 to stack 9
# P from stack 6 to stack 9
# P from stack 9 to stack 7
# D from stack 9 to stack 7
# P from stack 9 to stack 3
# N from stack 4 to stack 3
# C from stack 4 to stack 3
# V from stack 8 to stack 3
# V from stack 8 to stack 3
# V from stack 3 to stack 4
# V from stack 3 to stack 4
# C from stack 3 to stack 4
# N from stack 3 to stack 4
# P from stack 3 to stack 4
# N from stack 6 to stack 2
# R from stack 6 to stack 2
# W from stack 6 to stack 2
# Z from stack 6 to stack 2
# Z from stack 2 to stack 9
# W from stack 2 to stack 9
# R from stack 2 to stack 9
# N from stack 2 to stack 9
# Q from stack 2 to stack 9
# T from stack 2 to stack 9
# V from stack 2 to stack 9
# W from stack 2 to stack 9
# C from stack 6 to stack 5
# F from stack 2 to stack 3
# C from stack 2 to stack 3
# Q from stack 2 to stack 3
# L from stack 2 to stack 3
# S from stack 2 to stack 3
# D from stack 2 to stack 3
# D from stack 2 to stack 3
# P from stack 2 to stack 3
# F from stack 2 to stack 3
# J from stack 2 to stack 3
# L from stack 8 to stack 3
# S from stack 8 to stack 3
# W from stack 9 to stack 3
# V from stack 9 to stack 3
# T from stack 9 to stack 3
# Q from stack 9 to stack 3
# N from stack 9 to stack 3
# R from stack 9 to stack 3
# W from stack 9 to stack 3
# Z from stack 9 to stack 3
# G from stack 2 to stack 5
# C from stack 2 to stack 5
# T from stack 2 to stack 5
# H from stack 2 to stack 5
# M from stack 2 to stack 5
# D from stack 2 to stack 5
# G from stack 2 to stack 5
# Z from stack 2 to stack 5
# V from stack 2 to stack 5
# F from stack 2 to stack 4
# P from stack 2 to stack 3
# V from stack 5 to stack 6
# Z from stack 5 to stack 6
# G from stack 5 to stack 6
# D from stack 5 to stack 6
# M from stack 5 to stack 6
# H from stack 5 to stack 6
# T from stack 5 to stack 6
# C from stack 5 to stack 7
# P from stack 3 to stack 4
# Z from stack 3 to stack 4
# W from stack 3 to stack 4
# R from stack 3 to stack 4
# N from stack 3 to stack 4
# Q from stack 3 to stack 4
# T from stack 3 to stack 4
# V from stack 3 to stack 4
# W from stack 3 to stack 4
# S from stack 3 to stack 4
# L from stack 3 to stack 4
# J from stack 3 to stack 4
# F from stack 3 to stack 4
# C from stack 7 to stack 8
# D from stack 7 to stack 8
# P from stack 3 to stack 1
# D from stack 3 to stack 1
# D from stack 3 to stack 1
# S from stack 3 to stack 1
# L from stack 3 to stack 1
# G from stack 5 to stack 3
# D from stack 8 to stack 5
# L from stack 2 to stack 8
# P from stack 7 to stack 9
# F from stack 4 to stack 2
# J from stack 4 to stack 8
# L from stack 4 to stack 8
# S from stack 4 to stack 8
# W from stack 4 to stack 8
# V from stack 4 to stack 8
# T from stack 4 to stack 8
# Q from stack 4 to stack 8
# N from stack 4 to stack 8
# R from stack 4 to stack 8
# W from stack 4 to stack 8
# Z from stack 4 to stack 8
# P from stack 4 to stack 8
# F from stack 4 to stack 8
# P from stack 4 to stack 8
# N from stack 4 to stack 8
# C from stack 4 to stack 7
# V from stack 4 to stack 7
# V from stack 4 to stack 7
# H from stack 4 to stack 7
# T from stack 4 to stack 7
# T from stack 4 to stack 7
# T from stack 7 to stack 8
# T from stack 7 to stack 8
# H from stack 7 to stack 8
# V from stack 7 to stack 8
# V from stack 7 to stack 8
# C from stack 7 to stack 8
# T from stack 6 to stack 5
# C from stack 4 to stack 6
# P from stack 9 to stack 6
# T from stack 5 to stack 2
# D from stack 5 to stack 2
# P from stack 6 to stack 4
# C from stack 6 to stack 4
# H from stack 6 to stack 4
# M from stack 6 to stack 4
# D from stack 6 to stack 4
# G from stack 6 to stack 4
# L from stack 1 to stack 8
# S from stack 1 to stack 8
# D from stack 1 to stack 8
# D from stack 1 to stack 8
# P from stack 1 to stack 8
# L from stack 1 to stack 8
# G from stack 4 to stack 9
# D from stack 4 to stack 9
# M from stack 4 to stack 9
# H from stack 4 to stack 9
# C from stack 4 to stack 9
# P from stack 4 to stack 9
# Z from stack 6 to stack 1
# V from stack 6 to stack 1
# D from stack 2 to stack 9
# L from stack 8 to stack 1
# P from stack 8 to stack 1
# D from stack 8 to stack 1
# D from stack 8 to stack 1
# S from stack 8 to stack 1
# L from stack 8 to stack 1
# C from stack 8 to stack 1
# V from stack 8 to stack 1
# V from stack 8 to stack 1
# H from stack 8 to stack 1
# T from stack 8 to stack 1
# T from stack 8 to stack 1
# N from stack 8 to stack 1
# P from stack 8 to stack 1
# F from stack 8 to stack 1
# P from stack 8 to stack 1
# Z from stack 8 to stack 1
# W from stack 8 to stack 1
# R from stack 8 to stack 1
# N from stack 8 to stack 1
# Q from stack 8 to stack 1
# T from stack 8 to stack 1
# V from stack 8 to stack 1
# W from stack 8 to stack 1
# S from stack 8 to stack 1
# L from stack 8 to stack 1
# G from stack 3 to stack 7
# Q from stack 3 to stack 7
# C from stack 3 to stack 7
# F from stack 3 to stack 7
# T from stack 2 to stack 5
# F from stack 2 to stack 5
# L from stack 1 to stack 4
# S from stack 1 to stack 4
# W from stack 1 to stack 4
# V from stack 1 to stack 4
# T from stack 1 to stack 4
# Q from stack 1 to stack 4
# N from stack 1 to stack 4
# R from stack 1 to stack 4
# W from stack 1 to stack 4
# Z from stack 1 to stack 4
# P from stack 1 to stack 4
# F from stack 1 to stack 4
# P from stack 1 to stack 4
# N from stack 1 to stack 4
# T from stack 1 to stack 4
# T from stack 1 to stack 4
# D from stack 9 to stack 8
# P from stack 9 to stack 8
# C from stack 9 to stack 8
# C from stack 8 to stack 7
# P from stack 8 to stack 7
# D from stack 8 to stack 7
# F from stack 5 to stack 1
# T from stack 5 to stack 1
# C from stack 5 to stack 1
# H from stack 9 to stack 2
# M from stack 9 to stack 2
# D from stack 9 to stack 7
# G from stack 9 to stack 1
# T from stack 4 to stack 1
# T from stack 4 to stack 1
# N from stack 4 to stack 1
# P from stack 4 to stack 1
# F from stack 4 to stack 1
# P from stack 4 to stack 1
# Z from stack 4 to stack 1
# W from stack 4 to stack 1
# R from stack 4 to stack 9
# N from stack 4 to stack 9
# Q from stack 4 to stack 9
# T from stack 4 to stack 9
# M from stack 2 to stack 3
# M from stack 3 to stack 7
# J from stack 8 to stack 2
# L from stack 8 to stack 2
# V from stack 4 to stack 2
# W from stack 4 to stack 2
# S from stack 4 to stack 2
# L from stack 4 to stack 7
# L from stack 7 to stack 5
# M from stack 7 to stack 5
# D from stack 7 to stack 5
# D from stack 7 to stack 5
# P from stack 7 to stack 5
# C from stack 7 to stack 5
# F from stack 7 to stack 5
# C from stack 7 to stack 5
# Q from stack 7 to stack 5
# T from stack 9 to stack 8
# Q from stack 9 to stack 8
# N from stack 9 to stack 8
# Q from stack 5 to stack 7
# C from stack 5 to stack 7
# F from stack 5 to stack 7
# C from stack 5 to stack 7
# P from stack 5 to stack 7
# R from stack 9 to stack 5
# S from stack 2 to stack 6
# W from stack 2 to stack 6
# V from stack 2 to stack 6
# L from stack 2 to stack 6
# J from stack 2 to stack 6
# H from stack 2 to stack 6
# N from stack 8 to stack 2
# H from stack 6 to stack 5
# J from stack 6 to stack 5
# L from stack 6 to stack 5
# V from stack 6 to stack 5
# W from stack 6 to stack 5
# P from stack 7 to stack 4
# Q from stack 8 to stack 9
# T from stack 8 to stack 9
# C from stack 8 to stack 9
# C from stack 9 to stack 7
# T from stack 9 to stack 7
# Q from stack 9 to stack 7
# S from stack 6 to stack 4
# S from stack 4 to stack 1
# P from stack 4 to stack 1
# W from stack 5 to stack 8
# V from stack 5 to stack 8
# N from stack 2 to stack 9
# V from stack 8 to stack 9
# W from stack 8 to stack 9
# W from stack 9 to stack 3
# V from stack 9 to stack 3
# N from stack 9 to stack 3
# Q from stack 7 to stack 3
# T from stack 7 to stack 3
# C from stack 7 to stack 3
# C from stack 7 to stack 3
# F from stack 7 to stack 3
# C from stack 7 to stack 3
# Q from stack 7 to stack 3
# G from stack 7 to stack 3
# L from stack 5 to stack 8
# J from stack 5 to stack 8
# H from stack 5 to stack 8
# R from stack 5 to stack 8
# G from stack 3 to stack 9
# D from stack 5 to stack 8
# D from stack 5 to stack 8
# M from stack 5 to stack 8
# L from stack 5 to stack 3
# M from stack 8 to stack 6
# D from stack 8 to stack 6
# D from stack 8 to stack 6
# R from stack 8 to stack 6
# H from stack 8 to stack 6
# J from stack 8 to stack 6
# L from stack 3 to stack 9
# Q from stack 3 to stack 9
# C from stack 3 to stack 9
# F from stack 3 to stack 2
# C from stack 3 to stack 2
# C from stack 3 to stack 2
# T from stack 3 to stack 2
# Q from stack 3 to stack 2
# J from stack 6 to stack 4
# H from stack 6 to stack 4
# R from stack 6 to stack 4
# D from stack 6 to stack 4
# D from stack 6 to stack 4
# P from stack 1 to stack 5
# S from stack 1 to stack 5
# W from stack 1 to stack 5
# Z from stack 1 to stack 5
# P from stack 1 to stack 5
# F from stack 1 to stack 5
# P from stack 1 to stack 5
# N from stack 1 to stack 5
# T from stack 1 to stack 5
# T from stack 1 to stack 5
# G from stack 1 to stack 5
# C from stack 1 to stack 5
# T from stack 1 to stack 5
# F from stack 1 to stack 5
# F from stack 5 to stack 6
# T from stack 5 to stack 6
# C from stack 5 to stack 6
# G from stack 5 to stack 6
# T from stack 5 to stack 6
# T from stack 5 to stack 6
# N from stack 5 to stack 6
# P from stack 5 to stack 6
# N from stack 3 to stack 2
# V from stack 3 to stack 2
# C from stack 9 to stack 1
# Q from stack 9 to stack 1
# L from stack 9 to stack 1
# G from stack 9 to stack 1
# L from stack 8 to stack 7
# V from stack 2 to stack 3
# N from stack 2 to stack 3
# Q from stack 2 to stack 3
# T from stack 2 to stack 3
# C from stack 2 to stack 3
# C from stack 2 to stack 3
# F from stack 2 to stack 3
# F from stack 3 to stack 7
# C from stack 3 to stack 7
# C from stack 3 to stack 7
# T from stack 3 to stack 7
# Q from stack 3 to stack 7
# N from stack 3 to stack 7
# F from stack 5 to stack 3
# P from stack 5 to stack 3
# Z from stack 5 to stack 3
# Z from stack 3 to stack 9
# G from stack 1 to stack 5
# L from stack 1 to stack 5
# Q from stack 1 to stack 5
# C from stack 1 to stack 5
# H from stack 1 to stack 5
# V from stack 1 to stack 5
# V from stack 1 to stack 5
# C from stack 1 to stack 5
# L from stack 1 to stack 5
# S from stack 1 to stack 5
# D from stack 1 to stack 5
# D from stack 1 to stack 5
# Z from stack 9 to stack 7
# P from stack 3 to stack 1
# F from stack 3 to stack 1
# Z from stack 7 to stack 8
# Z from stack 8 to stack 7
# V from stack 3 to stack 6
# W from stack 3 to stack 6
# F from stack 1 to stack 9
# P from stack 1 to stack 9
# D from stack 5 to stack 6
# D from stack 5 to stack 6
# P from stack 9 to stack 7
# F from stack 9 to stack 7
# F from stack 7 to stack 3
# P from stack 7 to stack 3
# Z from stack 7 to stack 3
# N from stack 7 to stack 3
# Q from stack 7 to stack 3
# T from stack 7 to stack 3
# C from stack 7 to stack 3
# C from stack 7 to stack 3
# F from stack 7 to stack 3
# P from stack 1 to stack 5
# L from stack 1 to stack 5
# V from stack 1 to stack 5
# Z from stack 1 to stack 5
# Q from stack 1 to stack 5
# W from stack 1 to stack 5
# B from stack 1 to stack 5
# B from stack 5 to stack 2
# W from stack 5 to stack 2
# Q from stack 5 to stack 2
# Z from stack 5 to stack 2
# V from stack 5 to stack 2
# D from stack 6 to stack 8
# D from stack 6 to stack 8
# W from stack 6 to stack 8
# V from stack 6 to stack 8
# P from stack 6 to stack 8
# N from stack 6 to stack 8
# T from stack 6 to stack 8
# T from stack 6 to stack 8
# T from stack 8 to stack 9
# T from stack 8 to stack 9
# N from stack 8 to stack 9
# P from stack 8 to stack 9
# V from stack 8 to stack 9

# %%
get_top_crates(answer_stacks)
# Out:
# 'SVFDLGLWV'
